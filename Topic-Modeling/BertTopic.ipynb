# %%
import pandas as pd
from pprint import pprint
from nltk.corpus import stopwords
from gensim.utils import simple_preprocess
from gensim.models import Phrases, LdaModel
from gensim.models.phrases import Phraser
from gensim import corpora
from gensim.models.coherencemodel import CoherenceModel

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vldth\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Load the dataset
df = pd.read_csv('SentiTaglish_ProductsAndServices.csv')
print("Original dataset:")
print(df.head())
# Out:
# Original dataset:
#                                               review  sentiment
# 0  at first gumagana cya..pero pagnalowbat cya nd...          1
# 1  grabi pangalawa ko ng order sa shapee pero pur...          1
# 2  2l gray/black order ko. bakit 850ml lang po pi...          1
# 3  walang silbing product.. bwesit. di gumagana d...          1
# 4  d po maganda naman po yung neck fan, pero po n...          4

# %%
# Drop the sentiment column
reviews_df = df.drop(columns=['sentiment'])
print(reviews_df.head())
# Out:
#                                               review
# 0  at first gumagana cya..pero pagnalowbat cya nd...
# 1  grabi pangalawa ko ng order sa shapee pero pur...
# 2  2l gray/black order ko. bakit 850ml lang po pi...
# 3  walang silbing product.. bwesit. di gumagana d...
# 4  d po maganda naman po yung neck fan, pero po n...

# %%
documents = reviews_df['review'].astype(str).tolist()

# %%
#load tagalog stopwords function
def load_stopwords(filepath):
    with open(filepath, 'r', encoding='utf-8') as file:
        return set(line.strip() for line in file if line.strip())

# %%
# Define stopwords
english_stopwords = stopwords.words('english')

# Tagalog/Filipino stopwords 
tagalog_stopwords = load_stopwords("stopwords-new.txt")

combined_stopwords = set(english_stopwords).union(tagalog_stopwords)

# %%
# Preprocessing function
def preprocess_data(documents):
    return [
        [word for word in simple_preprocess(str(doc)) if word not in combined_stopwords]
        for doc in documents
    ]

# %%
# 1. Preprocess and tokenize your documents
processed_texts = preprocess_data(documents)  # Should return list of tokenized docs

# 2. Create bigram and trigram models
bigram = Phrases(processed_texts, min_count=3, threshold=5)
trigram = Phrases(bigram[processed_texts], threshold=5)

# 3. Convert to efficient Phrasers
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)

# 4. Apply phrase models
def make_ngrams(texts):
    bigram_texts = [bigram_mod[doc] for doc in texts]
    trigram_texts = [trigram_mod[doc] for doc in bigram_texts]
    return trigram_texts

ngrammed_texts = make_ngrams(processed_texts)

# 5. Join tokens back into strings
texts_for_bertopic = [' '.join(doc) for doc in ngrammed_texts]

# %%
from bertopic import BERTopic
print("BERTopic is working!")
# Out:
# BERTopic is working!

# %%
# Initialize BERTopic
topic_model = BERTopic(language="multilingual")

# Fit the model on the preprocessed texts
topics, probs = topic_model.fit_transform(texts_for_bertopic)

# %%
topic_info = topic_model.get_topic_info()
display(topic_info.sort_values(by='Count', ascending=False).head(20))  # Top 20 topics
# Out:
#     Topic  Count                                               Name  \
# 0      -1   3614                        -1_item_seller_product_kasi
# 1       0    993                           0_color_black_white_pink
# 2       1    514                  1_size_maliit_size_sizes_add_size
# 3       2    463                             2_dumating_sira_lng_ok
# 4       3    336               3_price_worth_worth_price_good_price
# 5       4    194                       4_food_place_masarap_service
# 6       5    181           5_order_shop_thank_seller_order_received
# 7       6    175                        6_damage_item_damaged_items
# 8       7    158        7_good_quality_good_maganda_quality_quality
# 9       8    156                        8_shoes_sandals_socks_boots
# 10      9    141        9_rider_ganda_ganda_kuya_rider_thank_seller
# 11     10    132        10_bubble_wrap_naka_bubble_wrap_box_fragile
# 12     11    129        11_order_order_ulit_nd_order_order_received
# 13     12    108         12_refund_return_sayang_pera_return_refund
# 14     13    106      13_battery_rechargeable_battery_life_gumagana
# 15     14     96               14_super_ganda_love_super_love_super
# 16     15     94                        15_scent_perfume_smell_amoy
# 17     16     93  16_god_bless_godbless_maraming_salamat_merry_c...
# 18     17     91                  17_sound_sounds_mic_sound_quality
# 19     18     85                18_mascara_lipstick_lashes_eyeliner
#
#                                        Representation  \
# 0   [item, seller, product, kasi, order, maganda, ...
# 1   [color, black, white, pink, blue, green, wrong...
# 2   [size, maliit_size, sizes, add_size, maliit, l...
# 3   [dumating, sira, lng, ok, agad, sana, maganda,...
# 4   [price, worth, worth_price, good_price, sakto_...
# 5   [food, place, masarap, service, staff, rice, c...
# 6   [order, shop, thank_seller, order_received, or...
# 7   [damage, item, damaged, items, box, product, t...
# 8   [good_quality, good, maganda_quality, quality,...
# 9   [shoes, sandals, socks, boots, slippers, legs,...
# 10  [rider, ganda_ganda, kuya_rider, thank_seller,...
# 11  [bubble_wrap, naka_bubble_wrap, box, fragile, ...
# 12  [order, order_ulit, nd_order, order_received, ...
# 13  [refund, return, sayang_pera, return_refund, p...
# 14  [battery, rechargeable, battery_life, gumagana...
# 15  [super_ganda, love, super_love, super, love_th...
# 16  [scent, perfume, smell, amoy, cloud, coconut, ...
# 17  [god_bless, godbless, maraming_salamat, merry_...
# 18  [sound, sounds, mic, sound_quality, basag, aud...
# 19  [mascara, lipstick, lashes, eyeliner, lips, dr...
#
#                                   Representative_Docs
# 0   [maganda mura thank order next_time, ganda ite...
# 1   [disappointed wrong_color purple pink, pink_bl...
# 2   [wrong_size binigay order size size binigay, c...
# 3   [sobrang nakakadismaya basta maka deliver lng ...
# 4   [maganda worth_price, ganda worth, okay lng pr...
# 5   [service good energy crew poor took mins food ...
# 6   [goods order_received maganda gumagana thank_s...
# 7   [ganda damage thankyou_seller, damage dumating...
# 8   [good_quality ganda, good_quality, maganda goo...
# 9   [maganda shoes price see_get, maganda shoes se...
# 10  [sakto thanks_seller rider well_packaged, than...
# 11  [requested bubble_wrap nasa plastic buti nasir...
# 12  [poor nasunod order st try mali agad wag_umord...
# 13  [good dumating sira dami process refund, nakak...
# 14  [kwenta gumagana bumili bagong battery everead...
# 15  [see_get super_ganda talaga, legit super_ganda...
# 16  [sure anong smell perfume toh disappointed, wa...
# 17  [good maraming_salamat sayo seller ganda item ...
# 18  [basag sounds case, basag sound mic sira paran...
# 19  [mascara nice tho hold curl lashes curl lashes...

# %%
# Get and sort topics
all_topics = topic_model.get_topic_info().sort_values(by='Count', ascending=False)

# Style with borders, aligned text, and background gradient
styled_html = all_topics.style.set_table_attributes('border="1" class="dataframe"') \
    .set_table_styles([
        {'selector': 'th', 'props': [('border', '1px solid black'), ('background-color', '#f2f2f2'), ('padding', '8px')]},
        {'selector': 'td', 'props': [('border', '1px solid black'), ('padding', '8px'), ('text-align', 'left')]},
        {'selector': 'table', 'props': [('border-collapse', 'collapse'), ('width', '100%')]}
    ]) \
    .background_gradient(subset=['Count'], cmap='Blues') \
    .set_properties(**{
        'white-space': 'pre-wrap',
        'text-align': 'left',
    })

# Save to HTML file
styled_html.to_html("all_bertopic_topics.html")

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_barchart(top_n_topics=20)
